# %% [markdown]
# <a href="https://colab.research.google.com/github/isaacmutuma/Tensor_fundamentals/blob/main/week4_neural_networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from torch import nn
# we create our shell first then make cutomizations inside the shell for our model
class NeuralNetwork(nn.Module):
  def __init__(self):
    super().__init__()# we set our the core foundation by accessing our pre built NN module
    #NN need flat input so our model shoulf flatten the input
    self.flatten= nn.Flatten()
    flat_image=flatten(input_image)
    # data enters in layers the nn.Linear layers
    self.linear_relu_stack =nn.Sequential (
        nn.Linear(28*28, 512),  # takes 784 inputs, outputs 512 numbers- Redundacy removed
        nn.ReLU()
        nn.Linear(512, 512),   # takes 512 inputs, outputs 512 numbers- The important featured refined
        nn.ReLU()
        nn.Linear(512, 10) #takes 512 inputs, outputs 10 numbers - a score for all the catergories we have
    )

    # Now we need our images to follow into each other-the linear layers
  def forward(self,x): # x is an input of a tensor(torch.)
    x=self.flatten(x) # flatten the pixels(input)
    x=self.linear_relu_stack(x) #3 pass the input thro the stack
    return x # the output of 10 scores

device ="cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# create the object(the model now comes to life) then we move it to the device it will run on
model =NeuralNetwork().to(device)
print(model)


#Now does our model make a prediction
x=torch.rand(1,28,28,device = device) # here we have a random image tensor as x

logits =model(x) # forward is called so x passes through all the phases and returns x
print("Raw logits:",logits) # raw scores par image class

# we need to convert the raw scores in probabilities to sum them up to 1
pred_prob=nn.Softmax(dim=1)(logits)
print("Probabiities",pred_prob)

# now our predicted class we now want the name of the highest prob class
class_pred=pred_prob.argmax(1)
print("Class_pred",class_pred)


# the models layers- when we import nn we are importing layers
# so we create a layer object an then call on the data

input_image = torch.rand(3,28,28)
# first flatten it using the first layer
flatten=nn.Flatten()
flat_image=flatten(input_image)
print(flat_image.shape)

"""
# the next layer needs configuration
layer1=nn.Linear(in_features=28*28, out_features=512)
hidden1=layer1(flat_image)# everything in between the input and output is hidden(the features outside the class)
print("hidden1:",hidden1.shape)#combines all inputs with weights → produces 512 values
                               #positive AND negative
#ReLU zeros out negatives → only positive features pass forward(Removing features of another class)
print(f"Before ReLU: {hidden1.shape}")
hidden1=nn.ReLU()(hidden1)
print(f"After ReLU: {hidden1.shape}")
print(hidden1[0][:10])
"""
# Out:
# Using cuda device
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): Linear(in_features=512, out_features=512, bias=True)
#     (2): Linear(in_features=512, out_features=10, bias=True)
#   )
# )
# Raw logits: tensor([[ 0.1411,  0.0760,  0.1273,  0.0311,  0.0429,  0.0295,  0.0061, -0.3133,
#          -0.1807,  0.0850]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Probabiities tensor([[0.1136, 0.1065, 0.1121, 0.1018, 0.1030, 0.1016, 0.0993, 0.0722, 0.0824,
#          0.1075]], device='cuda:0', grad_fn=<SoftmaxBackward0>)
# Class_pred tensor([0], device='cuda:0')
# torch.Size([3, 784])
# hidden1: torch.Size([3, 512])
# Before ReLU: torch.Size([3, 512])
# After ReLU: torch.Size([3, 512])
# tensor([0.1938, 0.0296, 0.3454, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#         0.0000], grad_fn=<SliceBackward0>)
