# %% [markdown]
# <a href="https://colab.research.google.com/github/isaacmutuma/Tensor_fundamentals/blob/main/week5_autograd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
x= torch.tensor(3.0,requires_grad=True)
y=x**2 # y was created by squaring x y =9

y.backward()# lets follow the trail backwards now
print(x.grad)#Given the current weight value,
            #how does the loss change when I adjust that weight?


x =torch.tensor([2.0,3.0,4.0],requires_grad=True)
y=(x**2).sum()

y.backward()
# Out:
# tensor(6.)

# %%
import torch
x= torch.tensor(3.0,requires_grad=True)
y=x**2 # y was created by squaring x y =9

y.backward()# lets follow the trail backwards now
print(x.grad)#Given the current weight value,
            #how does the loss change when I adjust that weight?


x =torch.tensor([2.0,3.0,4.0],requires_grad=True)
y=(x**2).sum()

y.backward()
# Out:
# tensor(6.)

# %%
import torch
x= torch.tensor(3.0,requires_grad=True)
y=x**2 # y was created by squaring x y =9

y.backward()# lets follow the trail backwards now
print(x.grad)#Given the current weight value,
            #how does the loss change when I adjust that weight?


x =torch.tensor([2.0,3.0,4.0],requires_grad=True)
y=(x**2).sum()

y.backward()
# Out:
# tensor(6.)

# %%
import torch
x= torch.tensor(3.0,requires_grad=True)
y=x**2 # y was created by squaring x y =9

y.backward()# lets follow the trail backwards now
print(x.grad)#Given the current weight value,
            #how does the loss change when I adjust that weight?


x =torch.tensor([2.0,3.0,4.0],requires_grad=True)
y=(x**2).sum()

y.backward()
# Out:
# tensor(6.)

# %%
import torch
x= torch.tensor(3.0,requires_grad=True)
y=x**2 # y was created by squaring x y =9

y.backward()# lets follow the trail backwards now
print(x.grad)#Given the current weight value,
            #how does the loss change when I adjust that weight?
#y.backward()    # call again
#print(x.grad)   # forward trail deleted so error

x =torch.tensor([2.0,3.0,4.0],requires_grad=True)
y=(x**2).sum()

y.backward()
print(x.grad)

# training loop will always have
optimizer.zero_grad() #clear all the gradients from the last step
loss.backward() #new gradients how does a change in weight affect the output
optimizer() #adjusts the weight in the right direction

#Gradient  →  tells us HOW each weight affects the loss does it increase the loss or reduce it
#Optimizer →  uses that info to ADJUST each weight to reduce loss
# Out:
# tensor(6.)
# tensor([4., 6., 8.])
