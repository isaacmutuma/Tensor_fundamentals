# %% [markdown]
# <a href="https://colab.research.google.com/github/isaacmutuma/Tensor_fundamentals/blob/main/week1_tensors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ta

# %%
import torch
import numpy as np
print(torch.__version__)

#creating tensors from data
data_one=[2,3,5,6] # creating a one dimensional tensor
x=torch.tensor(data_one)

data_two=[[5,6][7,8]] #creatinga two dimension tensor
y=torch.tensor(data_two)

#creating tensors from numpy
arr=np.array(data_one)#data one is used to create an np array
z=torch.from_numpy(arr)

#creating tensors from another tensor
w=torch.ones_like(x)

#creating a tensor using dimensions i.e shape
shape=(2,3)
b =torch.zeros(shape)
# creataing a tensor from random numbers and ones but specifying the shape
c= torch.rand(shape)
d=torch.ones(shape)

#operations on tensors
#moving a tensor to an accelerator
x=tensor.to('cuda')


#numpy like slicing and indexing
rowone  = sl[0]       # correct — first row, shape (4,)
colone  = sl[:, 0]    # fixed — colon not dot
lastcol = sl[:, -1]   # last column
lastrow = sl[-1]      # last row

#concatenating two
f3=tensor.cat([f1][f2])#passing the two tensors in to form one tensor

#matrix multiplication between two tensors
#dot prod
f4=f3@f2.T #the output is asingle value

#elementwise
f5=f2*f3
#single element tensor
data=[3,4,5,6,7]
x=torch.tensor(data)
y=x.sum()

#changing the tensor directly
data=[3,4,5,6,7]
z=tensor.add(10)#the output is going to have tensor where every element has 10added to it

#tensor to numpyarray
t=torch.tensor(data)
n=(t)
t= t.add(5)

#numpyarray to tensor
# Out:
# 2.10.0+cpu
# False
