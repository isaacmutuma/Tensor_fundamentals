# %% [markdown]
# <a href="https://colab.research.google.com/github/isaacmutuma/Tensor_fundamentals/blob/main/week2_datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import matplotlib. pyplot as plt
#using datsets you acess pre built data and
#transforms gives tools to process the data before feeding it to the model
# download FashionMNIST — the dataset you'll train on
training_data = datasets.FashionMNIST(
    root="data",#the downloaded files are saved in "data" folder
    train=True,# you just want the training portion on images
    download=True,# if files not on the computer download from the internet
    transform=transforms.ToTensor()#we convert the image into pytorch tensor
)
train_data_loader=DataLoader(
    training_data,
    batch_size=64,  #64, 1, 28, 28) batch size of 64 images with
                   #each image having a depth(greyscale is one feature)
                   #and each image has 28 by 28 pixels
    shuffle=True
)
#train_data give us our first batch, then iter makes sure they keep coming
#then next has the batches bundled up and they are then separated into image and labels
train_images,train_labels=next(iter(train_data_loader))
print("Batch image shape:", train_images.shape) #shape([64,1,28,28])
print("Batch image labels shape:",train_labels.shape) #shape([64])


#the progress bars are for showing the completed file downloads
print(len(training_data))        # should be 60000
print(training_data[0][0].shape) #the first item( a pair[0]) then access the image[0][0]
print(training_data[0][1])       # access the first item[0] then the items label[1]

labels_map = {
    0: "T-Shirt",
    1: "Trouser",
    2: "Pullover",
    3: "Dress",
    4: "Coat",
    5: "Sandal",
    6: "Shirt",
    7: "Sneaker",
    8: "Bag",
    9: "Ankle Boot",
} # this is for programmers readability to bridge between the that. number labels and their names


# create our own blank canvas (figure)where we add grids on for printing our images
figure= plt.figure(figsize=(8,8))

#create our own grid to print in should match the images you want to print
col,row= 3,3

#create an iteration for one image per slot in the grid
for i in range(1, col*rows +1):
  # we generate a random index tensor and from our training data and use .tem() to make it a python no index
  sample_index =torch.randint(len(training_data),size=(1,)).item()
  #use the random index to get an image and its label that are pre-determined by the map
  image,label= training_data[sample_index]
  #add a subplot inside the 3 by 3 grid to number our seats the rows and cols are not dynamic only i
  figure.addsub_plot(rows,col,i)
  #get every image a label based on the that label_map the label is a number so we print the string from the map
  plt.title(labels_map[label])
  #Turn off the x and y axis lines
  plt.axis.(off)
  #remove the dimension column to show the image and use cmap='gray' instead
  plt.imshow(im.squeeze(),cmap='grey')


#creating a custom dataset with my own images and labels
class customImageDataset(Dataset):
  #create the skull of any object the features that should be there in all
  def __innit__(self,img_dir,labels,transform =None ):#using self we now go into detail
    self.img_dir= img_dir   #the path to the folder where the actual image files live#the CSV loaded into memory — all filenames and their label
    self.img_label= pd.read_csv(labels_file)  #the CSV loaded into memory — all filenames and their label
    self.transform=transform        #the function to convert each image to a tensor when needed
#normally we have two objects from our class the training and test data
#How many images are in our dataset()
def __len__(self):
  return(self.img_labels)

#len(train_data)
#len(test_data)

#when the loader wants to get the images and their labels
def __getitem__(self, idx):
  #"images/boot001.jpg".
  img_path = os.path.join(self.img_dir, self.img_labels.iloc[idx, 0])
  image=decode_image(img_path) #load the image from the disk
  label=self.img_labels.iloc[idx, 1] #what csv belongs to this object
  if self.transform:
    image = self.transform(image)
 return image,label
# Out:
# Batch image shape: torch.Size([64, 1, 28, 28])
# Batch image labels shape: torch.Size([64])
# 60000
# torch.Size([1, 28, 28])
# 9
